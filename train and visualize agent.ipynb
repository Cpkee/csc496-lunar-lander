# %%
import gymnasium as gym
import pygame
import numpy as np
import matplotlib.pyplot as plt
import itertools
# Out:
# Failed to start the Kernel 'csc396 (Python 3.12.4)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. ENOSPC: no space left on device, write

# %%
import agent_class as agent

# %% [markdown]
# # Initialize environment and agent

# %%
# We first create the environment on which we will later train the agent
env = gym.make('LunarLander-v2')

# We need to know the dimensionality of the state space, as well as how many
# actions are possible
N_actions = env.action_space.n
observation, info = env.reset()
N_state = len(observation)

print('dimension of state space =',N_state)
print('number of actions =',N_actions)

# %%
# We create an instance of the agent class. 
# At initialization, we need to provide 
# - the dimensionality of the state space, as well as 
# - the number of possible actions

parameters = {'N_state':N_state, 'N_actions':N_actions}

# We create an instance of the PPO agent class with TUNED hyperparameters
parameters = {
    'N_state': N_state, 
    'N_actions': N_actions,
    
    # PPO-specific tuned parameters
    'horizon': 256,
    'n_epochs': 4,
    'minibatch_size': 64,
    'clip_epsilon': 0.2,
    'gae_lambda': 0.95,
    'gamma': 0.99,
    
    # Network architecture
    'layers_actor': [N_state, 256, 128, N_actions],
    'layers_critic': [N_state, 256, 128, 1],
    
    # Learning rates
    'learning_rate_actor': 1e-4,
    'learning_rate_critic': 1e-4,
    
    # Loss coefficients
    'value_loss_coef': 0.5,
    'entropy_coef': 0.01,
}

my_agent = agent.ppo(parameters=parameters)
# to train via the actor-critic algorithm, use this line:
# my_agent = agent.actor_critic(parameters=parameters)

# %% [markdown]
# # Train agent

# %%
# We train the agent on the LunarLander-v2 environment.
# Setting verbose=True allows us to follow the progress of the training

training_results = my_agent.train(environment=env,
                                verbose=True)

# %%
# the method my_agent.train() from the previous cell returns a dictionary
# with training stats, namely:
# - duration of each episode during training,
# - return of each episode during training
# - the total number of training epochs at the end of each episode
# - the total number of steps simulated at the end of each episode

training_results.keys()

# %% [markdown]
# # Plot training stats

# %%
# Plot both the return per episode and the duration per episode during
# training, together with their running average over 20 consecutive episodes

N = 50 # number of episodes for running average

def running_mean(x,N=20):
        x_out = np.zeros(len(x)-N,dtype=float)
        for i in range(len(x)-N):
                x_out[i] = np.mean(x[i:i+N+1])
        return x_out
        
def plot_returns_and_durations(training_results,filename=None):
    fig,axes = plt.subplots(2,1,figsize=(5,8))
    fig.subplots_adjust(hspace=0.0001)
    #
    # return as a function of episode
    ax = axes[0]
    x = training_results['epsiode_returns']
    t = np.arange(len(x)) + 1
    #
    ax.plot(t,x,label='training',color='dodgerblue',)
    # add running mean
    x = running_mean(x=x,N=N)
    t = np.arange(len(x)) + N
    ax.plot(t,x,color='black',label='running mean')
    #
    ax.axhline(230,ls='--',
               label='230',
                        color='red')
    #
    ax.set_ylim(-499,350)
    ax.set_xticks([])
    ax.set_xlim(0,len(t)+100)
    ax.set_xlabel(r'episode')
    ax.set_ylabel(r'return')
    #
    #
    ax = axes[1]
    x = training_results['episode_durations']
    t = np.arange(len(x)) + 1
    #
    ax.plot(t,x,label='training',color='dodgerblue',)
    # add running mean
    x = running_mean(x=x,N=N)
    t = np.arange(len(x)) + N
    ax.plot(t,x,color='black',label='running mean')
    #
    ax.axhline(1200,ls='--', # draw line outside of plot scale, 
                label='230', # to get the red dotted line into the legend
                        color='red')
    #
    ax.set_ylim(0,1100)
    ax.set_xlim(0,len(t)+100)
    ax.set_xlabel(r'episode')
    ax.set_ylabel(r'duration')
    ax.legend(loc='upper right',bbox_to_anchor=(1.,1.35),
                                framealpha=0.95,
                        fontsize=18)
    #
    plt.show()
    if filename != None:
        fig.savefig(filename,bbox_inches='tight')
    plt.close(fig)

plot_returns_and_durations(training_results=training_results)

# %% [markdown]
# # Create gameplay video using trained agent
#
# First we create a "live" video that pops up and shows Lunar Lander gameplay performed by the agent

# %%
# There is the issue that the game window freezes when running gym games 
# in jupyter notebooks, see https://github.com/openai/gym/issues/2433
# We here use the fix from that website, which is to use the following
# wrapper class:
class PyGameWrapper(gym.Wrapper):
    def render(self, **kwargs):
        retval = self.env.render( **kwargs)
        for event in pygame.event.get():
            pass
        return retval

# %%
# Create a wrapped environment
env = PyGameWrapper(gym.make('LunarLander-v2',render_mode='human'))

N_episodes = 20

result_string = 'Run {0}: duration = {1}, total return = {2:7.3f}'

for j in range(N_episodes):
    state, info = env.reset()

    total_reward = 0
    for i in itertools.count():
        #env.render()

        action = my_agent.act(state)
        state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        total_reward += reward

        if done:
            print(result_string.format(j+1,i+1,total_reward))
            break
    
env.close()

# %% [markdown]
# We also create a video file containing 20 games played by the agent

# %%
# !pip install gymnasium==0.29
# !pip install shimmy==1.3.0

# %% [markdown]
# # Diagnostic Tools for PPO Performance Analysis
#
# The following cells provide tools to:
# 1. Analyze training dynamics (policy loss, value loss, entropy, etc.)
# 2. Diagnose why learning plateaued
# 3. Perform hyperparameter tuning

# %%
# Enhanced PPO agent with diagnostic tracking
# This modifies the agent to track important metrics during training

def create_diagnostic_agent(N_state, N_actions, **kwargs):
    """
    Create a PPO agent that tracks detailed training diagnostics
    """
    # Default parameters
    params = {
        'N_state': N_state,
        'N_actions': N_actions,
        'horizon': 256,
        'n_epochs': 4,
        'minibatch_size': 64,
        'clip_epsilon': 0.2,
        'gae_lambda': 0.95,
        'gamma': 0.99,
        'layers_actor': [N_state, 256, 128, N_actions],
        'layers_critic': [N_state, 256, 128, 1],
        'learning_rate_actor': 1e-4,
        'learning_rate_critic': 1e-4,
        'value_loss_coef': 0.5,
        'entropy_coef': 0.01,
    }
    
    # Update with any provided kwargs
    params.update(kwargs)
    
    # Create agent
    diagnostic_agent = agent.ppo(parameters=params)
    
    # Add diagnostic tracking lists
    diagnostic_agent.diagnostics = {
        'policy_losses': [],
        'value_losses': [],
        'entropies': [],
        'kl_divergences': [],
        'clip_fractions': [],
        'explained_variances': [],
        'ratio_means': [],
        'ratio_stds': [],
    }
    
    # Monkey patch the run_optimization_step to track diagnostics
    original_optimization = diagnostic_agent.run_optimization_step
    
    def tracked_optimization():
        """Wrapper that tracks diagnostics"""
        import torch
        
        # Store states before update
        states = torch.stack([torch.FloatTensor(s) for s in diagnostic_agent.ppo_memory.states])
        actions = torch.LongTensor(diagnostic_agent.ppo_memory.actions)
        old_log_probs = torch.stack(diagnostic_agent.ppo_memory.log_probs)
        old_values = torch.stack(diagnostic_agent.ppo_memory.values)
        
        # Run the original optimization
        original_optimization()
        
        # Compute diagnostics after update
        with torch.no_grad():
            # Get new policy and values
            action_logits = diagnostic_agent.actor(states)
            new_values = diagnostic_agent.critic(states).squeeze()
            
            # Compute new log probs
            dist = torch.distributions.Categorical(logits=action_logits)
            new_log_probs = dist.log_prob(actions)
            
            # KL divergence approximation
            kl_div = (old_log_probs - new_log_probs).mean().item()
            
            # Entropy
            entropy = dist.entropy().mean().item()
            
            # Ratio statistics
            ratios = torch.exp(new_log_probs - old_log_probs)
            ratio_mean = ratios.mean().item()
            ratio_std = ratios.std().item() if len(ratios) > 1 else 0.0
            
            # Clip fraction
            clip_frac = ((ratios - 1.0).abs() > diagnostic_agent.clip_epsilon).float().mean().item()
            
            # Explained variance (how well value function predicts)
            if hasattr(diagnostic_agent.ppo_memory, 'returns') and diagnostic_agent.ppo_memory.returns is not None:
                returns = diagnostic_agent.ppo_memory.returns
                var_returns = torch.var(returns)
                explained_var = 1 - torch.var(returns - old_values) / (var_returns + 1e-8)
                explained_var = explained_var.item()
            else:
                explained_var = 0.0
            
            # Store diagnostics
            diagnostic_agent.diagnostics['kl_divergences'].append(kl_div)
            diagnostic_agent.diagnostics['entropies'].append(entropy)
            diagnostic_agent.diagnostics['ratio_means'].append(ratio_mean)
            diagnostic_agent.diagnostics['ratio_stds'].append(ratio_std)
            diagnostic_agent.diagnostics['clip_fractions'].append(clip_frac)
            diagnostic_agent.diagnostics['explained_variances'].append(explained_var)
    
    diagnostic_agent.run_optimization_step = tracked_optimization
    
    return diagnostic_agent

print("Diagnostic agent creation function ready!")

# %%
# Diagnostic Visualization Functions

def plot_training_diagnostics(training_results, diagnostics, window=100):
    """
    Plot comprehensive diagnostic information to understand training dynamics
    
    Args:
        training_results: Dict with 'epsiode_returns', 'episode_durations', etc.
        diagnostics: Dict with 'entropies', 'kl_divergences', 'clip_fractions', etc.
        window: Smoothing window size
    """
    fig, axes = plt.subplots(3, 2, figsize=(15, 12))
    fig.suptitle('PPO Training Diagnostics', fontsize=16, fontweight='bold')
    
    def smooth(data, window):
        """Apply moving average smoothing"""
        if len(data) < window:
            return data
        return np.convolve(data, np.ones(window)/window, mode='valid')
    
    # 1. Entropy (exploration indicator)
    ax = axes[0, 0]
    data = diagnostics['entropies']
    if len(data) > 0:
        ax.plot(data, alpha=0.3, color='blue')
        if len(data) >= window:
            ax.plot(smooth(data, window), color='darkblue', linewidth=2)
        ax.set_ylabel('Entropy', fontsize=12)
        ax.set_title('Policy Entropy (Exploration)', fontsize=12, fontweight='bold')
        ax.axhline(0.01, color='red', linestyle='--', alpha=0.5, label='low threshold')
        ax.grid(True, alpha=0.3)
        ax.legend()
    
    # 2. KL Divergence (policy change magnitude)
    ax = axes[0, 1]
    data = diagnostics['kl_divergences']
    if len(data) > 0:
        ax.plot(data, alpha=0.3, color='green')
        if len(data) >= window:
            ax.plot(smooth(data, window), color='darkgreen', linewidth=2)
        ax.set_ylabel('KL Divergence', fontsize=12)
        ax.set_title('KL Divergence (Policy Change)', fontsize=12, fontweight='bold')
        ax.axhline(0.01, color='orange', linestyle='--', alpha=0.5, label='target~0.01')
        ax.axhline(0.001, color='red', linestyle='--', alpha=0.5, label='too small')
        ax.grid(True, alpha=0.3)
        ax.legend()
    
    # 3. Clip Fraction (update constraint indicator)
    ax = axes[1, 0]
    data = diagnostics['clip_fractions']
    if len(data) > 0:
        ax.plot(data, alpha=0.3, color='purple')
        if len(data) >= window:
            ax.plot(smooth(data, window), color='darkviolet', linewidth=2)
        ax.set_ylabel('Clip Fraction', fontsize=12)
        ax.set_title('Fraction of Updates Clipped', fontsize=12, fontweight='bold')
        ax.axhline(0.5, color='red', linestyle='--', alpha=0.5, label='high (>0.5)')
        ax.axhline(0.1, color='orange', linestyle='--', alpha=0.5, label='low (<0.1)')
        ax.grid(True, alpha=0.3)
        ax.legend()
    
    # 4. Explained Variance (value function accuracy)
    ax = axes[1, 1]
    data = diagnostics['explained_variances']
    if len(data) > 0:
        ax.plot(data, alpha=0.3, color='brown')
        if len(data) >= window:
            ax.plot(smooth(data, window), color='saddlebrown', linewidth=2)
        ax.set_ylabel('Explained Variance', fontsize=12)
        ax.set_title('Value Function Accuracy', fontsize=12, fontweight='bold')
        ax.axhline(1.0, color='green', linestyle='--', alpha=0.5, label='perfect')
        ax.axhline(0.5, color='orange', linestyle='--', alpha=0.5, label='struggling')
        ax.grid(True, alpha=0.3)
        ax.legend()
    
    # 5. Episode Returns
    ax = axes[2, 0]
    returns = training_results['epsiode_returns']
    ax.plot(returns, alpha=0.3, label='raw', color='dodgerblue')
    if len(returns) >= window:
        ax.plot(np.arange(len(returns) - window + 1) + window - 1,
                smooth(returns, window), label='smoothed', color='navy', linewidth=2)
    ax.set_ylabel('Return', fontsize=12)
    ax.set_xlabel('Episode', fontsize=12)
    ax.set_title('Episode Returns', fontsize=12, fontweight='bold')
    ax.axhline(230, color='red', linestyle='--', label='solved (230)')
    ax.axhline(0, color='gray', linestyle='-', alpha=0.3)
    ax.grid(True, alpha=0.3)
    ax.legend()
    
    # 6. Ratio Statistics (how much policy is changing)
    ax = axes[2, 1]
    if len(diagnostics['ratio_means']) > 0:
        means = diagnostics['ratio_means']
        stds = diagnostics['ratio_stds']
        ax.plot(means, label='mean ratio', color='darkgreen', linewidth=2)
        if len(means) >= window:
            smoothed = smooth(means, window)
            ax.plot(np.arange(len(smoothed)) + window - 1, smoothed, 
                   label='smoothed mean', color='green', linewidth=2, linestyle='--')
        ax.axhline(1.0, color='black', linestyle='-', alpha=0.5, label='no change')
        ax.set_ylabel('Probability Ratio', fontsize=12)
        ax.set_xlabel('Update Step', fontsize=12)
        ax.set_title('Probability Ratio Statistics', fontsize=12, fontweight='bold')
        ax.grid(True, alpha=0.3)
        ax.legend()
    
    plt.tight_layout()
    plt.show()


def diagnose_plateau(training_results, diagnostics, plateau_start_episode=None, window=100):
    """
    Analyze what's happening at the plateau and provide recommendations
    
    Args:
        training_results: Dict with training statistics
        diagnostics: Dict with diagnostic metrics
        plateau_start_episode: Episode where plateau began (auto-detect if None)
        window: Window size for analysis
    """
    returns = np.array(training_results['epsiode_returns'])
    
    # Auto-detect plateau if not specified
    if plateau_start_episode is None:
        # Find where improvement stalls (where smoothed returns stop increasing significantly)
        if len(returns) > window * 2:
            smoothed = np.convolve(returns, np.ones(window)/window, mode='valid')
            diffs = np.diff(smoothed)
            # Find where improvement drops below threshold
            threshold = np.std(diffs) * 0.1
            plateaus = np.where(np.abs(diffs) < threshold)[0]
            if len(plateaus) > 0:
                plateau_start_episode = plateaus[0] + window
            else:
                plateau_start_episode = len(returns) // 2
        else:
            plateau_start_episode = len(returns) // 2
    
    print("="*70)
    print("PLATEAU ANALYSIS")
    print("="*70)
    print(f"Analyzing from episode {plateau_start_episode} onwards...")
    print()
    
    # Get plateau region data
    plateau_returns = returns[plateau_start_episode:]
    early_returns = returns[max(0, plateau_start_episode - 200):plateau_start_episode]
    
    # Corresponding diagnostic indices
    # Rough estimate: updates_per_episode ~= horizon / avg_episode_length
    approx_updates_per_ep = max(1, len(diagnostics['entropies']) // len(returns))
    plateau_start_update = plateau_start_episode * approx_updates_per_ep
    
    recommendations = []
    
    # 1. Check variance (stability)
    print("1. VARIANCE ANALYSIS (Learning Stability)")
    print("-" * 70)
    if len(early_returns) > 0:
        early_var = np.var(early_returns)
        plateau_var = np.var(plateau_returns)
        print(f"   Early phase variance: {early_var:.2f}")
        print(f"   Plateau phase variance: {plateau_var:.2f}")
        if plateau_var > 2 * early_var:
            print("   ⚠️  HIGH VARIANCE - Learning may be unstable!")
            recommendations.append("→ Try: Lower learning rate (current * 0.5)")
            recommendations.append("→ Try: Increase minibatch size (current * 2)")
        elif plateau_var < early_var * 0.5:
            print("   ✓ Variance decreased - policy becoming more consistent")
        else:
            print("   ○ Variance stable")
    print()
    
    # 2. Check entropy (exploration)
    print("2. EXPLORATION ANALYSIS (Entropy)")
    print("-" * 70)
    if len(diagnostics['entropies']) > plateau_start_update:
        recent_entropy = np.mean(diagnostics['entropies'][plateau_start_update:])
        early_entropy = np.mean(diagnostics['entropies'][:min(1000, len(diagnostics['entropies']))])
        print(f"   Early entropy: {early_entropy:.4f}")
        print(f"   Recent entropy: {recent_entropy:.4f}")
        if recent_entropy < 0.01:
            print("   ⚠️  LOW ENTROPY - Agent stopped exploring!")
            recommendations.append("→ Try: Increase entropy_coef (0.01 → 0.02 or 0.05)")
        elif recent_entropy < early_entropy * 0.3:
            print("   ⚠️  ENTROPY DECLINED SIGNIFICANTLY - Reduced exploration")
            recommendations.append("→ Consider: Increase entropy_coef slightly")
        else:
            print("   ✓ Entropy at healthy level")
    print()
    
    # 3. Check clipping (update constraint)
    print("3. UPDATE CLIPPING ANALYSIS")
    print("-" * 70)
    if len(diagnostics['clip_fractions']) > plateau_start_update:
        recent_clip = np.mean(diagnostics['clip_fractions'][plateau_start_update:])
        print(f"   Recent clip fraction: {recent_clip:.3f}")
        if recent_clip > 0.5:
            print("   ⚠️  HIGH CLIP FRACTION - Updates being heavily constrained!")
            recommendations.append("→ Try: Increase clip_epsilon (0.2 → 0.3)")
        elif recent_clip < 0.05:
            print("   ⚠️  LOW CLIP FRACTION - Clipping not active")
            recommendations.append("→ Consider: Decrease clip_epsilon (0.2 → 0.1)")
        else:
            print("   ✓ Clipping at reasonable level")
    print()
    
    # 4. Check value function
    print("4. VALUE FUNCTION ANALYSIS")
    print("-" * 70)
    if len(diagnostics['explained_variances']) > plateau_start_update:
        recent_exp_var = np.mean(diagnostics['explained_variances'][plateau_start_update:])
        print(f"   Recent explained variance: {recent_exp_var:.3f}")
        if recent_exp_var < 0.5:
            print("   ⚠️  LOW EXPLAINED VARIANCE - Value function struggling!")
            recommendations.append("→ Try: Larger critic network")
            recommendations.append("→ Try: Increase value_loss_coef (0.5 → 1.0)")
        elif recent_exp_var > 0.8:
            print("   ✓ Value function accurate")
        else:
            print("   ○ Value function moderate accuracy")
    print()
    
    # 5. Check KL divergence (policy change)
    print("5. POLICY CHANGE ANALYSIS (KL Divergence)")
    print("-" * 70)
    if len(diagnostics['kl_divergences']) > plateau_start_update:
        recent_kl = np.mean(diagnostics['kl_divergences'][plateau_start_update:])
        print(f"   Recent KL divergence: {recent_kl:.5f}")
        if recent_kl < 0.0001:
            print("   ⚠️  VERY SMALL POLICY CHANGES - Policy may be stuck!")
            recommendations.append("→ Try: Increase learning rate (current * 2)")
            recommendations.append("→ Try: Increase clip_epsilon")
        elif recent_kl > 0.05:
            print("   ⚠️  LARGE POLICY CHANGES - May be unstable")
            recommendations.append("→ Try: Decrease learning rate (current * 0.5)")
        else:
            print("   ✓ Policy changes at reasonable rate")
    print()
    
    # 6. Progress analysis
    print("6. LEARNING PROGRESS")
    print("-" * 70)
    early_mean = np.mean(returns[:min(100, len(returns))])
    late_mean = np.mean(returns[-100:])
    best_mean = np.max([np.mean(returns[i:i+100]) for i in range(0, len(returns)-100, 10)])
    print(f"   Initial mean (first 100 ep): {early_mean:.1f}")
    print(f"   Recent mean (last 100 ep): {late_mean:.1f}")
    print(f"   Best mean (any 100 ep window): {best_mean:.1f}")
    print(f"   Total improvement: {late_mean - early_mean:.1f}")
    print(f"   Distance to solved (230): {230 - late_mean:.1f}")
    
    if late_mean < best_mean - 50:
        print("   ⚠️  PERFORMANCE DEGRADATION - Agent forgot previous good policy!")
        recommendations.append("→ Critical: Learning rate too high OR")
        recommendations.append("→ Critical: Need more training epochs per update")
    print()
    
    # Summary
    print("="*70)
    print("RECOMMENDATIONS SUMMARY")
    print("="*70)
    if len(recommendations) == 0:
        print("✓ Training appears healthy! Consider:")
        print("  → Training for more episodes")
        print("  → Fine-tuning learning rate")
    else:
        print("Priority actions to try:")
        for i, rec in enumerate(recommendations, 1):
            print(f"{i}. {rec}")
    print("="*70)
    
    return plateau_start_episode

print("Diagnostic functions ready!")

# %%
# Hyperparameter Tuning Functions

def quick_hyperparam_test(param_name, values, base_params, N_episodes=1000, N_eval_runs=10):
    """
    Test different values for a single hyperparameter
    
    Args:
        param_name: Name of parameter to tune (e.g., 'learning_rate_actor')
        values: List of values to try
        base_params: Base parameter configuration dict
        N_episodes: Number of training episodes per test
        N_eval_runs: Number of evaluation runs after training
    
    Returns:
        results: List of dicts with test results
    """
    import time
    
    results = []
    env_test = gym.make('LunarLander-v2')
    
    print(f"\n{'='*70}")
    print(f"HYPERPARAMETER TUNING: {param_name}")
    print(f"{'='*70}\n")
    
    for i, value in enumerate(values):
        print(f"Test {i+1}/{len(values)}: {param_name} = {value}")
        print("-" * 70)
        
        # Create test configuration
        test_params = base_params.copy()
        test_params[param_name] = value
        
        # Create and train agent
        test_agent = agent.ppo(parameters=test_params)
        
        start_time = time.time()
        training_results = test_agent.train(environment=env_test, N_episodes=N_episodes, verbose=False)
        train_time = time.time() - start_time
        
        # Evaluate trained agent
        eval_returns = []
        for _ in range(N_eval_runs):
            state, info = env_test.reset()
            total_reward = 0
            done = False
            while not done:
                action = test_agent.act(state)
                state, reward, terminated, truncated, info = env_test.step(action)
                done = terminated or truncated
                total_reward += reward
            eval_returns.append(total_reward)
        
        # Calculate metrics
        eval_mean = np.mean(eval_returns)
        eval_std = np.std(eval_returns)
        final_100_mean = np.mean(training_results['epsiode_returns'][-100:])
        best_100_mean = max([np.mean(training_results['epsiode_returns'][j:j+100]) 
                            for j in range(0, len(training_results['epsiode_returns'])-100, 10)])
        
        result = {
            'param_value': value,
            'eval_mean': eval_mean,
            'eval_std': eval_std,
            'final_100_mean': final_100_mean,
            'best_100_mean': best_100_mean,
            'train_time': train_time,
        }
        results.append(result)
        
        print(f"  Training time: {train_time:.1f}s")
        print(f"  Final 100 ep mean: {final_100_mean:.1f}")
        print(f"  Best 100 ep mean: {best_100_mean:.1f}")
        print(f"  Eval mean ± std: {eval_mean:.1f} ± {eval_std:.1f}")
        print()
    
    env_test.close()
    
    # Summary
    print(f"{'='*70}")
    print("SUMMARY")
    print(f"{'='*70}")
    best_idx = np.argmax([r['eval_mean'] for r in results])
    print(f"\nBest value: {param_name} = {results[best_idx]['param_value']}")
    print(f"  Eval performance: {results[best_idx]['eval_mean']:.1f} ± {results[best_idx]['eval_std']:.1f}")
    print(f"  Training time: {results[best_idx]['train_time']:.1f}s")
    
    # Plot results
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    param_values = [r['param_value'] for r in results]
    eval_means = [r['eval_mean'] for r in results]
    eval_stds = [r['eval_std'] for r in results]
    train_times = [r['train_time'] for r in results]
    
    # Performance plot
    ax = axes[0]
    ax.errorbar(range(len(results)), eval_means, yerr=eval_stds, 
                marker='o', capsize=5, linewidth=2, markersize=8)
    ax.set_xticks(range(len(results)))
    ax.set_xticklabels([str(v) for v in param_values], rotation=45)
    ax.set_xlabel(param_name, fontsize=12)
    ax.set_ylabel('Evaluation Mean Return', fontsize=12)
    ax.set_title('Performance vs Hyperparameter', fontsize=12, fontweight='bold')
    ax.axhline(230, color='red', linestyle='--', alpha=0.5, label='solved')
    ax.grid(True, alpha=0.3)
    ax.legend()
    
    # Training time plot
    ax = axes[1]
    ax.bar(range(len(results)), train_times, color='skyblue', edgecolor='navy')
    ax.set_xticks(range(len(results)))
    ax.set_xticklabels([str(v) for v in param_values], rotation=45)
    ax.set_xlabel(param_name, fontsize=12)
    ax.set_ylabel('Training Time (s)', fontsize=12)
    ax.set_title('Training Time vs Hyperparameter', fontsize=12, fontweight='bold')
    ax.grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.show()
    
    return results


def compare_hyperparameter_configs(configs, config_names, N_episodes=1500, N_eval_runs=10):
    """
    Compare multiple complete hyperparameter configurations
    
    Args:
        configs: List of parameter dicts to compare
        config_names: List of names for each configuration
        N_episodes: Number of training episodes
        N_eval_runs: Number of evaluation runs
    
    Returns:
        results: List of dicts with comparison results
    """
    import time
    
    results = []
    env_test = gym.make('LunarLander-v2')
    
    print(f"\n{'='*70}")
    print("HYPERPARAMETER CONFIGURATION COMPARISON")
    print(f"{'='*70}\n")
    
    for i, (config, name) in enumerate(zip(configs, config_names)):
        print(f"\nConfiguration {i+1}/{len(configs)}: {name}")
        print("-" * 70)
        print("Parameters:")
        for key, val in config.items():
            if key not in ['N_state', 'N_actions', 'layers_actor', 'layers_critic']:
                print(f"  {key}: {val}")
        print()
        
        # Create and train agent
        test_agent = agent.ppo(parameters=config)
        
        start_time = time.time()
        training_results = test_agent.train(environment=env_test, N_episodes=N_episodes, verbose=False)
        train_time = time.time() - start_time
        
        # Evaluate
        eval_returns = []
        for _ in range(N_eval_runs):
            state, info = env_test.reset()
            total_reward = 0
            done = False
            while not done:
                action = test_agent.act(state)
                state, reward, terminated, truncated, info = env_test.step(action)
                done = terminated or truncated
                total_reward += reward
            eval_returns.append(total_reward)
        
        # Metrics
        eval_mean = np.mean(eval_returns)
        eval_std = np.std(eval_returns)
        final_100_mean = np.mean(training_results['epsiode_returns'][-100:])
        
        result = {
            'config_name': name,
            'config': config,
            'eval_mean': eval_mean,
            'eval_std': eval_std,
            'final_100_mean': final_100_mean,
            'train_time': train_time,
            'training_results': training_results,
        }
        results.append(result)
        
        print(f"Results:")
        print(f"  Training time: {train_time:.1f}s")
        print(f"  Final 100 ep mean: {final_100_mean:.1f}")
        print(f"  Eval mean ± std: {eval_mean:.1f} ± {eval_std:.1f}")
    
    env_test.close()
    
    # Summary and visualization
    print(f"\n{'='*70}")
    print("COMPARISON SUMMARY")
    print(f"{'='*70}\n")
    
    # Sort by performance
    sorted_results = sorted(results, key=lambda x: x['eval_mean'], reverse=True)
    for i, res in enumerate(sorted_results):
        print(f"{i+1}. {res['config_name']}")
        print(f"   Eval: {res['eval_mean']:.1f} ± {res['eval_std']:.1f}")
        print(f"   Time: {res['train_time']:.1f}s")
    
    # Plot comparison
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Performance comparison
    ax = axes[0]
    means = [r['eval_mean'] for r in results]
    stds = [r['eval_std'] for r in results]
    x_pos = np.arange(len(results))
    ax.bar(x_pos, means, yerr=stds, capsize=5, color='skyblue', edgecolor='navy', alpha=0.7)
    ax.set_xticks(x_pos)
    ax.set_xticklabels(config_names, rotation=45, ha='right')
    ax.set_ylabel('Evaluation Mean Return', fontsize=12)
    ax.set_title('Configuration Performance Comparison', fontsize=12, fontweight='bold')
    ax.axhline(230, color='red', linestyle='--', alpha=0.5, label='solved (230)')
    ax.axhline(0, color='gray', linestyle='-', alpha=0.3)
    ax.grid(True, alpha=0.3, axis='y')
    ax.legend()
    
    # Training curves
    ax = axes[1]
    for res in results:
        returns = res['training_results']['epsiode_returns']
        smoothed = np.convolve(returns, np.ones(50)/50, mode='valid')
        ax.plot(smoothed, label=res['config_name'], linewidth=2)
    ax.set_xlabel('Episode', fontsize=12)
    ax.set_ylabel('Return (50-ep average)', fontsize=12)
    ax.set_title('Training Curves', fontsize=12, fontweight='bold')
    ax.axhline(230, color='red', linestyle='--', alpha=0.5, label='solved')
    ax.grid(True, alpha=0.3)
    ax.legend()
    
    plt.tight_layout()
    plt.show()
    
    return results

print("Hyperparameter tuning functions ready!")

# %% [markdown]
# ## Example Usage: Analyze Your Current Training
#
# To analyze your existing training results (from the 2500 episode run), you need to:
# 1. Re-train with a diagnostic agent to collect the metrics
# 2. Use the diagnostic tools to analyze performance
#
# Run the cells below to get insights into your PPO training.

# %%
# Example 1: Train with diagnostic tracking (short run for demonstration)
# This will train a diagnostic agent and track all metrics

# Create diagnostic agent with your current best hyperparameters
diagnostic_agent = create_diagnostic_agent(
    N_state=N_state,
    N_actions=N_actions,
    horizon=256,
    n_epochs=4,
    minibatch_size=64,
    clip_epsilon=0.2,
    learning_rate_actor=1e-4,
    learning_rate_critic=1e-4,
)

# Train (use fewer episodes for quick demo, or increase for full analysis)
env_diag = gym.make('LunarLander-v2')
diagnostic_training_results = diagnostic_agent.train(
    environment=env_diag,
    N_episodes=500,  # Increase this to 2500+ for full analysis
    verbose=True
)
env_diag.close()

print("\n✓ Diagnostic training complete!")
print(f"Collected {len(diagnostic_agent.diagnostics['entropies'])} diagnostic data points")

# %%
# Example 2: Visualize diagnostic plots
# This shows you what's happening during training

plot_training_diagnostics(diagnostic_training_results, diagnostic_agent.diagnostics, window=50)

# %%
# Example 3: Run plateau diagnosis
# This analyzes why learning might have plateaued and gives recommendations

diagnose_plateau(diagnostic_training_results, diagnostic_agent.diagnostics)

# %% [markdown]
# ## Example Usage: Hyperparameter Tuning
#
# Below are examples of how to tune hyperparameters systematically.

# %%
# Example 4: Test different learning rates
# This will train multiple agents with different learning rates and compare them

# Define base configuration
base_config = {
    'N_state': N_state,
    'N_actions': N_actions,
    'horizon': 256,
    'n_epochs': 4,
    'minibatch_size': 64,
    'clip_epsilon': 0.2,
    'gae_lambda': 0.95,
    'gamma': 0.99,
    'layers_actor': [N_state, 256, 128, N_actions],
    'layers_critic': [N_state, 256, 128, 1],
    'learning_rate_actor': 1e-4,  # This will be varied
    'learning_rate_critic': 1e-4,  # This will be varied
    'value_loss_coef': 0.5,
    'entropy_coef': 0.01,
}

# Test different learning rates
# WARNING: This will take some time! Each test trains for 1000 episodes
# Comment out or reduce N_episodes if you want faster results

# lr_results = quick_hyperparam_test(
#     param_name='learning_rate_actor',
#     values=[5e-5, 1e-4, 2e-4, 5e-4],
#     base_params=base_config,
#     N_episodes=1000,
#     N_eval_runs=10
# )

print("Uncomment the code above to run hyperparameter tuning for learning rate")

# %%
# Example 5: Compare multiple complete configurations
# This compares different complete hyperparameter sets

# Define configurations to compare
config1 = base_config.copy()
config1.update({'learning_rate_actor': 1e-4, 'learning_rate_critic': 1e-4})

config2 = base_config.copy()
config2.update({'learning_rate_actor': 5e-5, 'learning_rate_critic': 5e-5})

config3 = base_config.copy()
config3.update({'entropy_coef': 0.02})  # Higher exploration

# WARNING: This will take time! Trains 3 agents for 1500 episodes each
# Uncomment to run:

# comparison_results = compare_hyperparameter_configs(
#     configs=[config1, config2, config3],
#     config_names=['Current (1e-4)', 'Lower LR (5e-5)', 'Higher Entropy'],
#     N_episodes=1500,
#     N_eval_runs=10
# )

print("Uncomment the code above to run configuration comparison")

# %%
import gymnasium as gym
from gymnasium.wrappers.monitoring import video_recorder
import logging

logging.basicConfig(level=logging.INFO)    
env = gym.make('LunarLander-v2', render_mode="rgb_array")  
video = video_recorder.VideoRecorder(env, './video.mp4')      

N_episodes = 10

result_string = 'Run {0}: duration = {1}, total return = {2:7.3f}'

for j in range(N_episodes):
    state, info = env.reset()

    total_reward = 0
    for i in itertools.count():
        video.capture_frame()

        action = my_agent.act(state)
        state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        total_reward += reward

        if done:
            print(result_string.format(j+1,i+1,total_reward))
            break

video.close()
env.close()
